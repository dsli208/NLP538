# %%
# %tensorflow_version 2.x

# %%
ls
# Out:
# sample_data/

# %%
cd /content
# Out:
# /content

# %%
rm -r NLP538

# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
repo_name = input('Repo name: ')

cmd_string = 'git clone https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: dsli208
# Password: ··········
# Repo name: NLP538

# %%
cat data/train.conll

# %%
cd NLP538/assignment3/assignment3
# Out:
# /content/NLP538/assignment3/assignment3

# %%
ls data
# Out:
# dev.conll  fixture.conll  test.conll  train.conll

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
ls
# Out:
# colab_notes.md  data/              evaluate.py     hw3readme.md  predict.py
# constants.py    download_glove.sh  experiments.sh  lib/          train.py

# %%
# !bash ./download_glove.sh
# Out:
# + GLOVE_URL=http://nlp.stanford.edu/data/glove.6B.zip
# + cd data/
# + wget http://nlp.stanford.edu/data/glove.6B.zip
# --2019-11-16 04:10:19--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-11-16 04:10:19--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2019-11-16 04:10:20--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# ...

# %%
# !python train.py data/train.conll data/dev.conll
# Out:
# 2019-11-16 12:36:22.392144: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-16 12:36:22.398041: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-11-16 12:36:22.398296: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2d2bb80 executing computations on platform Host. Devices:
# 2019-11-16 12:36:22.398326: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2019-11-16 12:36:22.400429: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-16 12:36:22.522420: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python train.py data/fixture.conll data/dev.conll
# Out:
# 2019-11-12 20:25:10.293016: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-12 20:25:10.299440: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-12 20:25:10.299658: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19392c0 executing computations on platform Host. Devices:
# 2019-11-12 20:25:10.299723: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2019-11-12 20:25:10.301959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-12 20:25:10.361404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python predict.py serialization_dirs/default \
                  data/dev.conll \
                  --predictions-file dev_predictions.conll
# Out:
# Reading data
# 41816it [00:00, 222186.63it/s]
# 2019-11-16 12:57:50.425342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-16 12:57:50.428322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-16 12:57:50.428990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-11-16 12:57:50.429349: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-16 12:57:50.430976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# ...

# %%
# !python evaluate.py serialization_dirs/default \
                   data/dev.conll \
                   dev_predictions.conll
# Out:
# Reading data
# 41816it [00:00, 369566.03it/s]
# 41767it [00:00, 424086.86it/s]
# Reading vocabulary
# Evaluating
# UAS: 26.320255565538584
# UASnoPunc: 29.360835243188184
# LAS: 0.022461814914645103
# LASnoPunc: 0.02546473134708429
#
# UEM: 0.47086521483225424
# UEMnoPunc: 0.47086521483225424
# ROOT: 0.47086521483225424

# %%
ls
# Out:
# colab_notes.md  download_glove.sh  hw3readme.md  __pycache__/
# constants.py    evaluate.py        lib/          serialization_dirs/
# data/           experiments.sh     predict.py    train.py

# %%
cat serialization_dirs/wo_glove/metrics.txt
# Out:
# UAS: 26.320255565538584
# UASnoPunc: 29.360835243188184
# LAS: 0.022461814914645103
# LASnoPunc: 0.02546473134708429
#
# UEM: 0.47086521483225424
# UEMnoPunc: 0.47086521483225424
# ROOT: 0.47086521483225424

# %%
# !bash ./experiments.sh
# Out:
# 2019-11-16 04:19:19.095094: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-16 04:19:19.101498: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-11-16 04:19:19.101784: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2ad5b80 executing computations on platform Host. Devices:
# 2019-11-16 04:19:19.101817: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2019-11-16 04:19:19.104296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-16 04:19:19.228727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !zip -r serialization_dirs.zip serialization_dirs/
# Out:
#   adding: serialization_dirs/ (stored 0%)
#   adding: serialization_dirs/wo_emb_tune/ (stored 0%)
#   adding: serialization_dirs/wo_emb_tune/model.ckpt.data-00000-of-00002 (deflated 60%)
#   adding: serialization_dirs/wo_emb_tune/checkpoint (deflated 42%)
#   adding: serialization_dirs/wo_emb_tune/model.ckpt.data-00001-of-00002 (deflated 7%)
#   adding: serialization_dirs/wo_emb_tune/config.json (deflated 30%)
#   adding: serialization_dirs/wo_emb_tune/model.ckpt.index (deflated 39%)
#   adding: serialization_dirs/wo_emb_tune/metrics.txt (deflated 31%)
#   adding: serialization_dirs/wo_emb_tune/vocab.pickle (deflated 49%)
#   adding: serialization_dirs/basic/ (stored 0%)
#   adding: serialization_dirs/basic/model.ckpt.data-00000-of-00002 (deflated 60%)
#   adding: serialization_dirs/basic/checkpoint (deflated 42%)
#   adding: serialization_dirs/basic/model.ckpt.data-00001-of-00002 (deflated 7%)
#   adding: serialization_dirs/basic/config.json (deflated 30%)
# ...

# %%
from google.colab import files
files.download('serialization_dirs.zip')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-13-45a25055e271> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('serialization_dirs.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# ...

# %%
from google.colab import files
files.download('dev_predictions.conll')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-10-a637de784b7b> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('dev_predictions.conll')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# ...

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'filename.csv'})
uploaded.SetContentFile('filename.csv')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-249bc4181387> in <module>()
#      14 # Create & upload a file.
#      15 uploaded = drive.CreateFile({'title': 'filename.csv'})
# ---> 16 uploaded.SetContentFile('filename.csv')
#      17 uploaded.Upload()
#      18 print('Uploaded file with ID {}'.format(uploaded.get('id')))
#
# /usr/local/lib/python3.6/dist-packages/pydrive/files.py in SetContentFile(self, filename)
#     167     :type filename: str.
#     168     """
# --> 169     self.content = open(filename, 'rb')
#     170     if self.get('title') is None:
#     171       self['title'] = filename
#
# FileNotFoundError: [Errno 2] No such file or directory: 'filename.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !head -n 10 data/train.conll
# Out:
# 1	In	_	IN	IN	_	45	prep	_	_
# 2	an	_	DT	DT	_	5	det	_	_
# 3	Oct.	_	NNP	NNP	_	5	nn	_	_
# 4	19	_	CD	CD	_	5	num	_	_
# 5	review	_	NN	NN	_	1	pobj	_	_
# 6	of	_	IN	IN	_	5	prep	_	_
# 7	``	_	``	``	_	9	punct	_	_
# 8	The	_	DT	DT	_	9	det	_	_
# 9	Misanthrope	_	NN	NN	_	6	pobj	_	_
# 10	''	_	''	''	_	9	punct	_	_

# %%
cd ..
# Out:
# /content

# %%
d=[]
while(1):
  d.append('1')
